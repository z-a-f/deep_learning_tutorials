# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

ax = plt.gca()

isinstance(ax, mpl.axes.Axes)
# Out:
# True

# %%
from class_utils import visualization

# %%
from sklearn.datasets import make_moons

# %%
x, y = make_moons()
x.shape
# Out:
# (100, 2)

# %%
import numpy as np
visualization.visualize_dataset((x, y), estimator=lambda x: np.logical_and(x[:, 0] > 0, x[:, 1] > 0))
# Out:
# <AxesSubplot:>
